# %% [markdown]
# <a href="https://colab.research.google.com/github/KIMMIKSIK/SeNet_2020074575KIMMINSIK/blob/main/SeNet_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import package

# model
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchsummary import summary
from torch import optim

# dataset and transformation
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import os

# display images
from torchvision import utils
import matplotlib.pyplot as plt
# %matplotlib inline

# utils
import numpy as np
from torchsummary import summary
import time
import copy

# %%
# specify path to data
path2data = '/content/drive/MyDrive/'

# if not exists the path, make the directory
if not os.path.exists(path2data):
    os.mkdir(path2data)

# load dataset
train_ds = datasets.STL10(path2data, split='train', download=True, transform=transforms.ToTensor())
val_ds = datasets.STL10(path2data, split='test', download=True, transform=transforms.ToTensor())

print(len(train_ds))
print(len(val_ds))
# Out:
# Downloading http://ai.stanford.edu/~acoates/stl10/stl10_binary.tar.gz to /content/drive/MyDrive/stl10_binary.tar.gz
# 100%|██████████| 2640397119/2640397119 [01:01<00:00, 42851216.22it/s]
# Extracting /content/drive/MyDrive/stl10_binary.tar.gz to /content/drive/MyDrive/
# Files already downloaded and verified
# 5000
# 8000

# %%
# define transformation
transformation = transforms.Compose([
                    transforms.ToTensor(),
                    transforms.Resize(224)
])

# apply transformation to dataset
train_ds.transform = transformation
val_ds.transform = transformation

# %%
# make dataloade
train_dl = DataLoader(train_ds, batch_size=32, shuffle=True)
val_dl = DataLoader(val_ds, batch_size=32, shuffle=True)

# %%
# check sample images
def show(img, y=None):
    npimg = img.numpy()
    npimg_tr = np.transpose(npimg, (1, 2, 0))
    plt.imshow(npimg_tr)

    if y is not None:
        plt.title('labels:' + str(y))

np.random.seed(13)
torch.manual_seed(0)

grid_size=4
rnd_ind = np.random.randint(0, len(train_ds), grid_size)

x_grid = [train_ds[i][0] for i in rnd_ind]
y_grid = [val_ds[i][1] for i in rnd_ind]

x_grid = utils.make_grid(x_grid, nrow=grid_size, padding=2)
plt.figure(figsize=(10,10))
show(x_grid, y_grid)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(

# %%
class SEBlock(nn.Module):
    def __init__(self, in_channels, r=16):
        super().__init__()
        self.squeeze = nn.AdaptiveAvgPool2d((1,1))
        self.excitation = nn.Sequential(
            nn.Linear(in_channels, in_channels // r),
            nn.ReLU(),
            nn.Linear(in_channels // r, in_channels),
            nn.Sigmoid()
        )

    def forward(self, x):
        x = self.squeeze(x)
        x = x.view(x.size(0), -1)
        x = self.excitation(x)
        x = x.view(x.size(0), x.size(1), 1, 1)
        return x

# %%
# check SEBlock
x = torch.randn(3, 32, 16, 16)
model = SEBlock(32)
output = model(x)
print(output.size())
# Out:
# torch.Size([3, 32, 1, 1])

# %%
# Depthwise Separable Convolution
class Depthwise(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super().__init__()

        self.depthwise = nn.Sequential(
            nn.Conv2d(in_channels, in_channels, 3, stride=stride, padding=1, groups=in_channels, bias=False),
            nn.BatchNorm2d(in_channels),
            nn.ReLU6(),
        )

        self.pointwise = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 1, stride=1, padding=0, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU6(),
        )

        self.seblock = SEBlock(out_channels)

    def forward(self, x):
        x = self.depthwise(x)
        x = self.pointwise(x)
        x = self.seblock(x) * x
        return x


# BasicConv2d
class BasicConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, **kwargs):
        super().__init__()

        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=kernel_size, **kwargs),
            nn.BatchNorm2d(out_channels),
            nn.ReLU6()
        )

    def forward(self, x):
        x = self.conv(x)
        return x


# MobileNetV1
class MobileNet(nn.Module):
    def __init__(self, width_multiplier, num_classes=10, init_weights=True):
        super().__init__()
        self.init_weights=init_weights
        alpha = width_multiplier

        self.conv1 = BasicConv2d(3, int(32*alpha), 3, stride=2, padding=1)
        self.conv2 = Depthwise(int(32*alpha), int(64*alpha), stride=1)
        # down sample
        self.conv3 = nn.Sequential(
            Depthwise(int(64*alpha), int(128*alpha), stride=2),
            Depthwise(int(128*alpha), int(128*alpha), stride=1)
        )
        # down sample
        self.conv4 = nn.Sequential(
            Depthwise(int(128*alpha), int(256*alpha), stride=2),
            Depthwise(int(256*alpha), int(256*alpha), stride=1)
        )
        # down sample
        self.conv5 = nn.Sequential(
            Depthwise(int(256*alpha), int(512*alpha), stride=2),
            Depthwise(int(512*alpha), int(512*alpha), stride=1),
            Depthwise(int(512*alpha), int(512*alpha), stride=1),
            Depthwise(int(512*alpha), int(512*alpha), stride=1),
            Depthwise(int(512*alpha), int(512*alpha), stride=1),
            Depthwise(int(512*alpha), int(512*alpha), stride=1),
        )
        # down sample
        self.conv6 = nn.Sequential(
            Depthwise(int(512*alpha), int(1024*alpha), stride=2)
        )
        # down sample
        self.conv7 = nn.Sequential(
            Depthwise(int(1024*alpha), int(1024*alpha), stride=2)
        )

        self.avg_pool = nn.AdaptiveAvgPool2d((1,1))
        self.linear = nn.Linear(int(1024*alpha), num_classes)

        # weights initialization
        if self.init_weights:
            self._initialize_weights()

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.conv5(x)
        x = self.conv6(x)
        x = self.conv7(x)
        x = self.avg_pool(x)
        x = x.view(x.size(0), -1)
        x = self.linear(x)
        return x

    # weights initialization function
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, 0, 0.01)
                nn.init.constant_(m.bias, 0)

def mobilenet(alpha=1, num_classes=10):
    return MobileNet(alpha, num_classes)

# %%
# check MobileNetV1
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
x = torch.randn(3, 3, 224, 224).to(device)
model = mobilenet().to(device)
output = model(x)
print(output.size())
# Out:
# torch.Size([3, 10])

# %%
# print model summary
summary(model, (3, 224, 224), device=device.type)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 112, 112]             896
#        BatchNorm2d-2         [-1, 32, 112, 112]              64
#              ReLU6-3         [-1, 32, 112, 112]               0
#        BasicConv2d-4         [-1, 32, 112, 112]               0
#             Conv2d-5         [-1, 32, 112, 112]             288
#        BatchNorm2d-6         [-1, 32, 112, 112]              64
#              ReLU6-7         [-1, 32, 112, 112]               0
#             Conv2d-8         [-1, 64, 112, 112]           2,048
#        BatchNorm2d-9         [-1, 64, 112, 112]             128
[-1, 512, 14, 14]               0
# AdaptiveAvgPool2d-76            [-1, 512, 1, 1]               0
#            Linear-77                   [-1, 32]          16,416
#              ReLU-78                   [-1, 32]               0
#            Linear-79                  [-1, 512]          16,896
#           Sigmoid-80                  [-1, 512]               0
#           SEBlock-81            [-1, 512, 1, 1]               0
#         Depthwise-82          [-1, 512, 14, 14]               0
#            Conv2d-83          [-1, 512, 14, 14]           4,608
#       BatchNorm2d-84          [-1, 512, 14, 14]           1,024
#             ReLU6-85          [-1, 512, 14, 14]               0
#            Conv2d-86          [-1, 512, 14, 14]         262,144
#       BatchNorm2d-87          [-1, 512, 14, 14]           1,024
#             ReLU6-88          [-1, 512, 14, 14]               0
# AdaptiveAvgPool2d-89            [-1, 512, 1, 1]               0
#            Linear-90                   [-1, 32]          16,416
#              ReLU-91                   [-1, 32]               0
#            Linear-92                  [-1, 512]          16,896
#           Sigmoid-93                  [-1, 512]               0
#           SEBlock-94            [-1, 512, 1, 1]               0
#         Depthwise-95          [-1, 512, 14, 14]               0
#            Conv2d-96          [-1, 512, 14, 14]           4,608
#       BatchNorm2d-97          [-1, 512, 14, 14]           1,024
#             ReLU6-98          [-1, 512, 14, 14]               0
#            Conv2d-99          [-1, 512, 14, 14]         262,144
#      BatchNorm2d-100          [-1, 512, 14, 14]           1,024
#            ReLU6-101          [-1, 512, 14, 14]               0
# AdaptiveAvgPool2d-102            [-1, 512, 1, 1]               0
#           Linear-103                   [-1, 32]          16,416
#             ReLU-104                   [-1, 32]               0
#           Linear-105                  [-1, 512]          16,896
#          Sigmoid-106                  [-1, 512]               0
#          SEBlock-107            [-1, 512, 1, 1]               0
#        Depthwise-108          [-1, 512, 14, 14]               0
#           Conv2d-109          [-1, 512, 14, 14]           4,608
#      BatchNorm2d-110          [-1, 512, 14, 14]           1,024
#            ReLU6-111          [-1, 512, 14, 14]               0
#           Conv2d-112          [-1, 512, 14, 14]         262,144
#      BatchNorm2d-113          [-1, 512, 14, 14]           1,024
#            ReLU6-114          [-1, 512, 14, 14]               0
# AdaptiveAvgPool2d-115            [-1, 512, 1, 1]               0
#           Linear-116                   [-1, 32]          16,416
#             ReLU-117                   [-1, 32]               0
#           Linear-118                  [-1, 512]          16,896
#          Sigmoid-119                  [-1, 512]               0
#          SEBlock-120            [-1, 512, 1, 1]               0
#        Depthwise-121          [-1, 512, 14, 14]               0
#           Conv2d-122          [-1, 512, 14, 14]           4,608
#      BatchNorm2d-123          [-1, 512, 14, 14]           1,024
#            ReLU6-124          [-1, 512, 14, 14]               0
#           Conv2d-125          [-1, 512, 14, 14]         262,144
#      BatchNorm2d-126          [-1, 512, 14, 14]           1,024
#            ReLU6-127          [-1, 512, 14, 14]               0
# AdaptiveAvgPool2d-128            [-1, 512, 1, 1]               0
#           Linear-129                   [-1, 32]          16,416
#             ReLU-130                   [-1, 32]               0
#           Linear-131                  [-1, 512]          16,896
#          Sigmoid-132                  [-1, 512]               0
#          SEBlock-133            [-1, 512, 1, 1]               0
#        Depthwise-134          [-1, 512, 14, 14]               0
#           Conv2d-135          [-1, 512, 14, 14]           4,608
#      BatchNorm2d-136          [-1, 512, 14, 14]           1,024
#            ReLU6-137          [-1, 512, 14, 14]               0
#           Conv2d-138          [-1, 512, 14, 14]         262,144
#      BatchNorm2d-139          [-1, 512, 14, 14]           1,024
#            ReLU6-140          [-1, 512, 14, 14]               0
# AdaptiveAvgPool2d-141            [-1, 512, 1, 1]               0
#           Linear-142                   [-1, 32]          16,416
#             ReLU-143                   [-1, 32]               0
#           Linear-144                  [-1, 512]          16,896
#          Sigmoid-145                  [-1, 512]               0
#          SEBlock-146            [-1, 512, 1, 1]               0
#        Depthwise-147          [-1, 512, 14, 14]               0
#           Conv2d-148            [-1, 512, 7, 7]           4,608
#      BatchNorm2d-149            [-1, 512, 7, 7]           1,024
#            ReLU6-150            [-1, 512, 7, 7]               0
#           Conv2d-151           [-1, 1024, 7, 7]         524,288
#      BatchNorm2d-152           [-1, 1024, 7, 7]           2,048
#            ReLU6-153           [-1, 1024, 7, 7]               0
# AdaptiveAvgPool2d-154           [-1, 1024, 1, 1]               0
#           Linear-155                   [-1, 64]          65,600
#             ReLU-156                   [-1, 64]               0
#           Linear-157                 [-1, 1024]          66,560
#          Sigmoid-158                 [-1, 1024]               0
#          SEBlock-159           [-1, 1024, 1, 1]               0
#        Depthwise-160           [-1, 1024, 7, 7]               0
#           Conv2d-161           [-1, 1024, 4, 4]           9,216
#      BatchNorm2d-162           [-1, 1024, 4, 4]           2,048
#            ReLU6-163           [-1, 1024, 4, 4]               0
#           Conv2d-164           [-1, 1024, 4, 4]       1,048,576
#      BatchNorm2d-165           [-1, 1024, 4, 4]           2,048
#            ReLU6-166           [-1, 1024, 4, 4]               0
# AdaptiveAvgPool2d-167           [-1, 1024, 1, 1]               0
#           Linear-168                   [-1, 64]          65,600
#             ReLU-169                   [-1, 64]               0
#           Linear-170                 [-1, 1024]          66,560
#          Sigmoid-171                 [-1, 1024]               0
#          SEBlock-172           [-1, 1024, 1, 1]               0
#        Depthwise-173           [-1, 1024, 4, 4]               0
# AdaptiveAvgPool2d-174           [-1, 1024, 1, 1]               0
#           Linear-175                   [-1, 10]          10,250
# ================================================================
# Total params: 3,703,326
# Trainable params: 3,703,326
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 137.54
# Params size (MB): 14.13
# Estimated Total Size (MB): 152.24
# ----------------------------------------------------------------

# %%
# define loss function, optimizer, lr_scheduler
loss_func = nn.CrossEntropyLoss(reduction='sum')
opt = optim.Adam(model.parameters(), lr=0.01)

from torch.optim.lr_scheduler import ReduceLROnPlateau
lr_scheduler = ReduceLROnPlateau(opt, mode='min', factor=0.1, patience=10)


# get current lr
def get_lr(opt):
    for param_group in opt.param_groups:
        return param_group['lr']


# calculate the metric per mini-batch
def metric_batch(output, target):
    pred = output.argmax(1, keepdim=True)
    corrects = pred.eq(target.view_as(pred)).sum().item()
    return corrects


# calculate the loss per mini-batch
def loss_batch(loss_func, output, target, opt=None):
    loss_b = loss_func(output, target)
    metric_b = metric_batch(output, target)

    if opt is not None:
        opt.zero_grad()
        loss_b.backward()
        opt.step()

    return loss_b.item(), metric_b


# calculate the loss per epochs
def loss_epoch(model, loss_func, dataset_dl, sanity_check=False, opt=None):
    running_loss = 0.0
    running_metric = 0.0
    len_data = len(dataset_dl.dataset)

    for xb, yb in dataset_dl:
        xb = xb.to(device)
        yb = yb.to(device)
        output = model(xb)

        loss_b, metric_b = loss_batch(loss_func, output, yb, opt)

        running_loss += loss_b

        if metric_b is not None:
            running_metric += metric_b

        if sanity_check is True:
            break

    loss = running_loss / len_data
    metric = running_metric / len_data
    return loss, metric


# function to start training
def train_val(model, params):
    num_epochs=params['num_epochs']
    loss_func=params['loss_func']
    opt=params['optimizer']
    train_dl=params['train_dl']
    val_dl=params['val_dl']
    sanity_check=params['sanity_check']
    lr_scheduler=params['lr_scheduler']
    path2weights=params['path2weights']

    loss_history = {'train': [], 'val': []}
    metric_history = {'train': [], 'val': []}

    best_loss = float('inf')
    best_model_wts = copy.deepcopy(model.state_dict())
    start_time = time.time()

    for epoch in range(num_epochs):
        current_lr = get_lr(opt)
        print('Epoch {}/{}, current lr= {}'.format(epoch, num_epochs-1, current_lr))

        model.train()
        train_loss, train_metric = loss_epoch(model, loss_func, train_dl, sanity_check, opt)
        loss_history['train'].append(train_loss)
        metric_history['train'].append(train_metric)

        model.eval()
        with torch.no_grad():
            val_loss, val_metric = loss_epoch(model, loss_func, val_dl, sanity_check)
        loss_history['val'].append(val_loss)
        metric_history['val'].append(val_metric)

        if val_loss < best_loss:
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            torch.save(model.state_dict(), path2weights)
            print('Copied best model weights!')

        lr_scheduler.step(val_loss)
        if current_lr != get_lr(opt):
            print('Loading best model weights!')
            model.load_state_dict(best_model_wts)

        print('train loss: %.6f, val loss: %.6f, accuracy: %.2f, time: %.4f min' %(train_loss, val_loss, 100*val_metric, (time.time()-start_time)/60))
        print('-'*10)

    model.load_state_dict(best_model_wts)
    return model, loss_history, metric_history

# %%
# define the training parameters
params_train = {
    'num_epochs':100,
    'optimizer':opt,
    'loss_func':loss_func,
    'train_dl':train_dl,
    'val_dl':val_dl,
    'sanity_check':False,
    'lr_scheduler':lr_scheduler,
    'path2weights':'./models/weights.pt',
}

# check the directory to save weights.pt
def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSerror:
        print('Error')
createFolder('./models')

# %%
model, loss_hist, metric_hist = train_val(model, params_train)
# Out:
# Epoch 0/99, current lr= 0.01
# Copied best model weights!
# train loss: 1.919903, val loss: 1.939862, accuracy: 23.90, time: 1.0448 min
# ----------
# Epoch 1/99, current lr= 0.01
# Copied best model weights!
# train loss: 1.720904, val loss: 1.681366, accuracy: 28.45, time: 2.0734 min
# ----------
# Epoch 2/99, current lr= 0.01
# train loss: 1.651973, val loss: 1.851997, accuracy: 32.19, time: 3.0658 min
# ----------
# Epoch 3/99, current lr= 0.01
# train loss: 1.616675, val loss: 1.732586, accuracy: 33.76, time: 4.0516 min
# ----------
# Epoch 4/99, current lr= 0.01
# Copied best model weights!
# train loss: 1.552951, val loss: 1.622906, accuracy: 38.44, time: 5.0410 min
# ----------
# Epoch 5/99, current lr= 0.01
# Copied best model weights!
# train loss: 1.507548, val loss: 1.533248, accuracy: 42.31, time: 6.0340 min
# ----------
# Epoch 6/99, current lr= 0.01
# train loss: 1.444847, val loss: 1.708341, accuracy: 37.50, time: 7.0246 min
# ----------
# Epoch 7/99, current lr= 0.01
# Copied best model weights!
# train loss: 1.403982, val loss: 1.499735, accuracy: 43.86, time: 8.0193 min
# ----------
# Epoch 8/99, current lr= 0.01
# train loss: 1.301415, val loss: 1.508685, accuracy: 44.76, time: 9.0226 min
# ----------
# Epoch 9/99, current lr= 0.01
# Copied best model weights!
# train loss: 1.244954, val loss: 1.397552, accuracy: 48.70, time: 10.0288 min
# ----------
# Epoch 10/99, current lr= 0.01
# Copied best model weights!
# train loss: 1.151869, val loss: 1.284084, accuracy: 52.88, time: 11.0485 min
# ----------
# Epoch 11/99, current lr= 0.01
# Copied best model weights!
# train loss: 1.071535, val loss: 1.193753, accuracy: 56.71, time: 12.0401 min
# ----------
# Epoch 12/99, current lr= 0.01
# Copied best model weights!
# train loss: 1
# ----------
# Epoch 37/99, current lr= 0.0001
# Copied best model weights!
# train loss: 0.645544, val loss: 0.978656, accuracy: 64.51, time: 38.1280 min
# ----------
# Epoch 38/99, current lr= 0.0001
# train loss: 0.646519, val loss: 0.994837, accuracy: 64.09, time: 39.1312 min
# ----------
# Epoch 39/99, current lr= 0.0001
# train loss: 0.641370, val loss: 0.979107, accuracy: 64.89, time: 40.1308 min
# ----------
# Epoch 40/99, current lr= 0.0001
# train loss: 0.632325, val loss: 0.984813, accuracy: 64.68, time: 41.1407 min
# ----------
# Epoch 41/99, current lr= 0.0001
# train loss: 0.619351, val loss: 0.991952, accuracy: 64.69, time: 42.1625 min
# ----------
# Epoch 42/99, current lr= 0.0001
# train loss: 0.612199, val loss: 0.982927, accuracy: 64.51, time: 43.1653 min
# ----------
# Epoch 43/99, current lr= 0.0001
# train loss: 0.618686, val loss: 0.992035, accuracy: 64.46, time: 44.1567 min
# ----------
# Epoch 44/99, current lr= 0.0001
# train loss: 0.605057, val loss: 0.984359, accuracy: 64.85, time: 45.1526 min
# ----------
# Epoch 45/99, current lr= 0.0001
# train loss: 0.596087, val loss: 0.984034, accuracy: 64.89, time: 46.1471 min
# ----------
# Epoch 46/99, current lr= 0.0001
# train loss: 0.584388, val loss: 0.994903, accuracy: 64.64, time: 47.1412 min
# ----------
# Epoch 47/99, current lr= 0.0001
# train loss: 0.579720, val loss: 0.983800, accuracy: 65.06, time: 48.1386 min
# ----------
# Epoch 48/99, current lr= 0.0001
# Loading best model weights!
# train loss: 0.582734, val loss: 0.987177, accuracy: 64.79, time: 49.1439 min
# ----------
# Epoch 49/99, current lr= 1e-05
# train loss: 0.635442, val loss: 0.983360, accuracy: 64.58, time: 50.1458 min
# ----------
# Epoch 50/99, current lr= 1e-05
# train loss: 0.640875, val loss: 0.984504, accuracy: 64.60, time: 51.1548 min
# ----------
# Epoch 51/99, current lr= 1e-05
# train loss: 0.637951, val loss: 0.984341, accuracy: 64.38, time: 52.1475 min
# ----------
# Epoch 52/99, current lr= 1e-05
# Copied best model weights!
# train loss: 0.632340, val loss: 0.978477, accuracy: 64.65, time: 53.1445 min
# ----------
# Epoch 53/99, current lr= 1e-05
# train loss: 0.632602, val loss: 0.986212, accuracy: 64.33, time: 54.1436 min
# ----------
# Epoch 54/99, current lr= 1e-05
# train loss: 0.636865, val loss: 0.980691, accuracy: 64.84, time: 55.1480 min
# ----------
# Epoch 55/99, current lr= 1e-05
# train loss: 0.638498, val loss: 0.979103, accuracy: 64.62, time: 56.1486 min
# ----------
# Epoch 56/99, current lr= 1e-05
# Copied best model weights!
# train loss: 0.638561, val loss: 0.977570, accuracy: 64.81, time: 57.1427 min
# ----------
# Epoch 57/99, current lr= 1e-05
# train loss: 0.632963, val loss: 0.982110, accuracy: 64.44, time: 58.1400 min
# ----------
# Epoch 58/99, current lr= 1e-05
# train loss: 0.626804, val loss: 0.981493, accuracy: 64.95, time: 59.1358 min
# ----------
# Epoch 59/99, current lr= 1e-05
# train loss: 0.641051, val loss: 0.982164, accuracy: 64.35, time: 60.1579 min
# ----------
# Epoch 60/99, current lr= 1e-05
# train loss: 0.632811, val loss: 0.977722, accuracy: 64.75, time: 61.1557 min
# ----------
# Epoch 61/99, current lr= 1e-05
# train loss: 0.631508, val loss: 0.983203, accuracy: 64.60, time: 62.1601 min
# ----------
# Epoch 62/99, current lr= 1e-05
# train loss: 0.631873, val loss: 0.983727, accuracy: 64.62, time: 63.1660 min
# ----------
# Epoch 63/99, current lr= 1e-05
# Copied best model weights!
# train loss: 0.629537, val loss: 0.977289, accuracy: 64.94, time: 64.1627 min
# ----------
# Epoch 64/99, current lr= 1e-05
# train loss: 0.634963, val loss: 0.977332, accuracy: 64.71, time: 65.1583 min
# ----------
# Epoch 65/99, current lr= 1e-05
# train loss: 0.622474, val loss: 0.980995, accuracy: 64.69, time: 66.1540 min
# ----------
# Epoch 66/99, current lr= 1e-05
# train loss: 0.624401, val loss: 0.990413, accuracy: 64.33, time: 67.1534 min
# ----------
# Epoch 67/99, current lr= 1e-05
# train loss: 0.631982, val loss: 0.987840, accuracy: 64.65, time: 68.1515 min
# ----------
# Epoch 68/99, current lr= 1e-05
# train loss: 0.635168, val loss: 0.981024, accuracy: 64.60, time: 69.1836 min
# ----------
# Epoch 69/99, current lr= 1e-05
# train loss: 0.619737, val loss: 0.977343, accuracy: 64.66, time: 70.1827 min
# ----------
# Epoch 70/99, current lr= 1e-05
# train loss: 0.623203, val loss: 0.983893, accuracy: 64.76, time: 71.1792 min
# ----------
# Epoch 71/99, current lr= 1e-05
# train loss: 0.618540, val loss: 0.986529, accuracy: 64.48, time: 72.1736 min
# ----------
# Epoch 72/99, current lr= 1e-05
# train loss: 0.623440, val loss: 0.981528, accuracy: 64.64, time: 73.1698 min
# ----------
# Epoch 73/99, current lr= 1e-05
# train loss: 0.611538, val loss: 0.984612, accuracy: 64.53, time: 74.1660 min
# ----------
# Epoch 74/99, current lr= 1e-05
# Loading best model weights!
# train loss: 0.617193, val loss: 0.979266, accuracy: 64.79, time: 75.1677 min
# ----------
# Epoch 75/99, current lr= 1.0000000000000002e-06
# train loss: 0.629379, val loss: 0.979549, accuracy: 65.01, time: 76.1774 min
# ----------
# Epoch 76/99, current lr= 1.0000000000000002e-06
# train loss: 0.625794, val loss: 0.984338, accuracy: 64.46, time: 77.1719 min
# ----------
# Epoch 77/99, current lr= 1.0000000000000002e-06
# train loss: 0.627760, val loss: 0.984979, accuracy: 64.54, time: 78.1666 min
# ----------
# Epoch 78/99, current lr= 1.0000000000000002e-06
# train loss: 0.622002, val loss: 0.977455, accuracy: 64.80, time: 79.1771 min
# ----------
# Epoch 79/99, current lr= 1.0000000000000002e-06
# train loss: 0.622527, val loss: 0.979069, accuracy: 64.66, time: 80.1761 min
# ----------
# Epoch 80/99, current lr= 1.0000000000000002e-06
# Copied best model weights!
# train loss: 0.630811, val loss: 0.977131, accuracy: 64.71, time: 81.1950 min
# ----------
# Epoch 81/99, current lr= 1.0000000000000002e-06
# Copied best model weights!
# train loss: 0.625259, val loss: 0.976214, accuracy: 64.95, time: 82.2021 min
# ----------
# Epoch 82/99, current lr= 1.0000000000000002e-06
# Copied best model weights!
# train loss: 0.624629, val loss: 0.975956, accuracy: 64.84, time: 83.2002 min
# ----------
# Epoch 83/99, current lr= 1.0000000000000002e-06
# train loss: 0.622693, val loss: 0.977681, accuracy: 64.85, time: 84.1964 min
# ----------
# Epoch 84/99, current lr= 1.0000000000000002e-06
# train loss: 0.618192, val loss: 0.981485, accuracy: 64.58, time: 85.1886 min
# ----------
# Epoch 85/99, current lr= 1.0000000000000002e-06
# train loss: 0.623217, val loss: 0.983425, accuracy: 64.76, time: 86.1836 min
# ----------
# Epoch 86/99, current lr= 1.0000000000000002e-06
# train loss: 0.634651, val loss: 0.980101, accuracy: 64.65, time: 87.1791 min
# ----------
# Epoch 87/99, current lr= 1.0000000000000002e-06
# train loss: 0.626619, val loss: 0.978022, accuracy: 64.72, time: 88.1970 min
# ----------
# Epoch 88/99, current lr= 1.0000000000000002e-06
# train loss: 0.626282, val loss: 0.979067, accuracy: 64.79, time: 89.1997 min
# ----------
# Epoch 89/99, current lr= 1.0000000000000002e-06
# train loss: 0.626276, val loss: 0.983314, accuracy: 64.48, time: 90.2000 min
# ----------
# Epoch 90/99, current lr= 1.0000000000000002e-06
# train loss: 0.633126, val loss: 0.982209, accuracy: 64.55, time: 91.1924 min
# ----------
# Epoch 91/99, current lr= 1.0000000000000002e-06
# train loss: 0.624271, val loss: 0.991000, accuracy: 64.48, time: 92.1827 min
# ----------
# Epoch 92/99, current lr= 1.0000000000000002e-06
# train loss: 0.625459, val loss: 0.981413, accuracy: 64.72, time: 93.1768 min
# ----------
# Epoch 93/99, current lr= 1.0000000000000002e-06
# Loading best model weights!
# train loss: 0.623234, val loss: 0.976905, accuracy: 64.81, time: 94.1731 min
# ----------
# Epoch 94/99, current lr= 1.0000000000000002e-07
# train loss: 0.630823, val loss: 0.978624, accuracy: 64.69, time: 95.1729 min
# ----------
# Epoch 95/99, current lr= 1.0000000000000002e-07
# train loss: 0.628838, val loss: 0.979290, accuracy: 64.75, time: 96.1788 min
# ----------
# Epoch 96/99, current lr= 1.0000000000000002e-07
# train loss: 0.634336, val loss: 0.977883, accuracy: 64.83, time: 97.1813 min
# ----------
# Epoch 97/99, current lr= 1.0000000000000002e-07
# train loss: 0.630372, val loss: 0.978460, accuracy: 64.91, time: 98.1883 min
# ----------
# Epoch 98/99, current lr= 1.0000000000000002e-07
# train loss: 0.618630, val loss: 0.981584, accuracy: 64.74, time: 99.1824 min
# ----------
# Epoch 99/99, current lr= 1.0000000000000002e-07
# train loss: 0.627384, val loss: 0.976369, accuracy: 64.72, time: 100.1790 min
# ----------

# %%
num_epochs = params_train['num_epochs']

# plot loss progress
plt.title('Train_Val Loss')
plt.plot(range(1, num_epochs+1), loss_hist['train'], label='train')
plt.plot(range(1, num_epochs+1), loss_hist['val'], label='val')
plt.ylabel('Loss')
plt.xlabel('Training Epochs')
plt.legend()
plt.show()

# plot accuracy progress
plt.title('Train-Val Accuracy')
plt.plot(range(1, num_epochs+1), metric_hist['train'], label='train')
plt.plot(range(1, num_epochs+1), metric_hist['val'], label='val')
plt.ylabel('Accuracy')
plt.xlabel('Training Epochs')
plt.legend()
plt.show()
